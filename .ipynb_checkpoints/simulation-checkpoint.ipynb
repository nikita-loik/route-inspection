# %%
import sys

import random
import numpy as np
import matplotlib.pyplot as plt

import pandas as pd

import networkx as nx

import shapely as sh
from shapely import geometry

import utilities.common as uc

import utilities.get_random_city as grc

import utilities.get_graph as gg
import utilities.forge_graph as fg
import utilities.visualise_graph as vg

random.seed(0)

# %load_ext autoreload
# %autoreload 2

# %%
random_city = grc.get_random_city(
    city_size=[24, 16],
    frequencies=[0.3, 0.1, 0.1, 0.5]
    )
# grc.plot_area(random_city)
# Out:
# INFO: 2019-03-07 09:02:56,713: get_random_city.py: 58:
# 	895 segments
# 	145 one-way
# 	375 two-way

# %%
cg = gg.get_city_graph(random_city)
vg.visualise_city_graph(cg)
# Out:
# INFO: 2019-03-06 13:21:20,278: visualise_graph.py: 83:
# 	24 dead ends
# 	0 disconnected nodes

# %%
for n in cg.nodes():
    if ((len(cg.in_edges(n))==1)
        and (len(cg.out_edges(n))==1)
        and (list(cg.in_edges(n))[0][0] != list(cg.out_edges(n))[0][1])):
        print(n, list(cg.in_edges(n))[0], list(cg.out_edges(n))[0])
# Out:
# 157 (158, 157) (157, 142)
# 372 (371, 372) (372, 357)

# %%
cg.get_edge_data(*(158, 157))
# Out:
# {'weight': 0,
#  'segment_id': 322,
#  'geometry': <shapely.geometry.linestring.LineString at 0x1134fee80>,
#  'coordinates': [(10, 1), (10, 0)]}

# %%
v_i = np.array([head - tail
    for tail, head in zip(*i_segment['coordinates'])])
v_j = np.array([head - tail
    for tail, head in zip(*j_segment['coordinates'])])
cosine = np.vdot(v_i, v_j) / (np.linalg.norm(v_i) * np.linalg.norm(v_j))
determinant = np.linalg.det([v_i, v_j])
if determinant < 0:
    angle = 180 * np.arccos(cosine) / np.pi
else:
    angle = 360 - (180 * np.arccos(cosine) / np.pi)

# %%
mg = gg.get_manoeuvre_graph(random_city)
vg.visualise_manoeuvre_graph(mg)
print(len(mg.nodes()))
print(len(mg.edges()))
# 	straight drives: 464
# 	right turns: 461
# 	left turns: 474
# 	u-turns: 682
# Out:
# INFO: 2019-03-06 13:21:31,839: visualise_graph.py: 174:
# 	strongly connected: True
# 	disconnected nodes: 0
# 	straight drives: 843
# 	right turns: 0
# 	left turns: 0
# 	u-turns: 0
# 	dead ends: 0
# 346
# 843

# %%
dg = gg.get_random_district_graph(mg)
vg.visualise_manoeuvre_graph(dg)
# Out:
# INFO: 2019-03-06 15:10:35,031: get_graph.py: 203:
# district borders:
# west-east: 0 - 12
# south-north: 0 - 8
# INFO: 2019-03-06 15:10:35,035: visualise_graph.py: 174:
# 	strongly connected: False
# 	disconnected nodes: 5
# 	straight drives: 255
# 	right turns: 0
# 	left turns: 0
# 	u-turns: 0
# 	dead ends: 0

# %%
dg = fg.add_connecting_grafts(dg, mg)
vg.visualise_manoeuvre_graph(dg)
# Out:
# INFO: 2019-03-06 15:11:01,345: visualise_graph.py: 174:
# 	strongly connected: False
# 	disconnected nodes: 3
# 	straight drives: 264
# 	right turns: 0
# 	left turns: 0
# 	u-turns: 0
# 	dead ends: 0

# %%
icg = gg.get_inverted_graph(random_city)
print(len(icg.nodes()))
print(len(icg.edges()))
vg.visualise_manoeuvre_graph(icg)
# 	straight drives: 464
# 	right turns: 461
# 	left turns: 474
# 	u-turns: 682
# Out:
# INFO: 2019-03-06 15:13:49,992: visualise_graph.py: 174:
# 	strongly connected: True
# 	disconnected nodes: 0
# 	straight drives: 508
# 	right turns: 497
# 	left turns: 494
# 	u-turns: 724
# 	dead ends: 1
# 843
# 2223

# %%
idg = gg.get_random_district_graph(icg)
vg.visualise_manoeuvre_graph(idg)
# Out:
# INFO: 2019-03-06 15:14:31,905: get_graph.py: 203:
# district borders:
# west-east: 0 - 12
# south-north: 0 - 8
# INFO: 2019-03-06 15:14:31,911: visualise_graph.py: 174:
# 	strongly connected: False
# 	disconnected nodes: 6
# 	straight drives: 149
# 	right turns: 146
# 	left turns: 139
# 	u-turns: 224
# 	dead ends: 2

# %%
idg = fg.add_connecting_grafts(idg, icg)
vg.visualise_manoeuvre_graph(idg)
# Out:
# INFO: 2019-03-06 15:23:34,454: visualise_graph.py: 174:
# 	strongly connected: True
# 	disconnected nodes: 0
# 	straight drives: 339
# 	right turns: 336
# 	left turns: 335
# 	u-turns: 486
# 	dead ends: 1
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-16-ec9529782a7d> in <module>
# ----> 1 idg = fg.add_connecting_grafts(idg, icg)
#       2 vg.visualise_manoeuvre_graph(idg)
#
# ~/Documents/Projects/city_simulation/utilities/forge_graph.py in add_connecting_grafts(g, super_g)
#     105     edges_to_add = []
#     106     for n in get_grafting_nodes_and_edges(
# --> 107         g, super_g, condenced_g, 0, 1)['nodes_to_add']:
#     108         nodes_to_add.append(n)
#     109     for e in get_grafting_nodes_and_edges(
#
# ~/Documents/Projects/city_simulation/utilities/forge_graph.py in get_grafting_nodes_and_edges(g, super_g, condenced_g, source_node, target_node)
#      54         for i in range(len(nodes_to_add)-1)]
#      55
# ---> 56     for tail, head in super_g.in_edges(nodes_to_add[0]):
#      57         if tail in g.nodes:
#      58             edges_to_add.append((tail,head))
#
# IndexError: list index out of range

# %%
nx.is_strongly_connected(ig)

# %%
def prune_u_turns(
        g: nx.DiGraph):
    edges = list(g.edges())
    for e in edges:
        manoeuvre = g.get_edge_data(*e)['manoeuvre']
        if manoeuvre == 'make_u_turn':
            test_g = g.copy()
            test_g.remove_edge(*e)
            if nx.is_strongly_connected(test_g):
                inverted_graph.remove_edge(*e)
                
def prune_left_turns(
        g: nx.DiGraph):
    edges = list(g.edges())
    for e in edges:
        manoeuvre = g.get_edge_data(*e)['manoeuvre']
        if manoeuvre == 'turn_left':
            test_g = g.copy()
            test_g.remove_edge(*e)
            if nx.is_strongly_connected(test_g):
                inverted_graph.remove_edge(*e)

# %%
prune_u_turns(inverted_graph)
prune_left_turns(inverted_graph)

# %%
vis_g.visualise_graph(inverted_graph)

# %%
import geopandas as gpd

# %%
np.arange(0.5, 17.6 + 1.0, 1)

# %%
[-1, 5] > [0, 1]
